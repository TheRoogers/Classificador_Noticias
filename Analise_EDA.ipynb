# %% [markdown]
# Import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %% [markdown]
# ## Análise de dados exploratória (EDA)

# %% [markdown]
# ### Carregando o dataset

# %%
df = pd.read_csv('files/dataset.csv')

# %% [markdown]
# ### Verificar linhas duplicadas

# %%
df[df.duplicated()]
# Out:
#                                                    title  \
# 7268   São as águas de Marte fechando o verão. É prom...
# 11042  Ex-militante pela queda de Dilma se foca em co...
# 14357  São as águas de Marte fechando o verão. É prom...
# 37070  São as águas de Marte fechando o verão. É prom...
# 45187        Nota de dólar terá mulher pela primeira vez
# 45306  Faltava vontade política para implantar ciclov...
#
#                                                     text        date  \
# 7268   Dados colhidos por uma espaçonave da Nasa conf...  2015-09-28
# 11042  RESUMO - Ex-militante entusiasmada de grupos q...  2015-12-27
# 14357  Dados colhidos por uma espaçonave da Nasa conf...  2015-09-28
# 37070  Dados colhidos por uma espaçonave da Nasa conf...  2015-09-28
# 45187  O Departamento do Tesouro dos EUA anunciou que...  2015-06-18
# 45306  Ex-coordenadora do Departamento de Planejament...  2015-06-28
#
#         category subcategory
# 7268     ciencia         NaN
# 11042      poder         NaN
# 14357    ciencia         NaN
# 37070    ciencia         NaN
# 45187    mercado         NaN
# 45306  cotidiano         NaN

# %% [markdown]
# Removendo linhas duplicadas

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Conferindo se possui linhas duplicadas

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [title, text, date, category, subcategory]
# Index: []

# %% [markdown]
# ### Análise inicial

# %%
df.head()
# Out:
#                                                title  \
# 0  Haverá pressão por transparência no 'brexit', ...
# 1  Empresário confirma ter pago propina para obte...
# 2  Falta de ataques do São Paulo surpreende corin...
# 3  Líderes de comissão do Senado não veem sinais ...
# 4  Renan opera contra governo e reforma trabalhis...
#
#                                                 text        date category  \
# 0  As negociações do "brexit" devem ocorrer a por...  2017-03-31    mundo
# 1  O empresário Augusto Ribeiro de Mendonça Neto,...  2015-03-02    poder
# 2  Cássio sorriu e pareceu sem jeito com a pergun...  2015-02-19  esporte
# 3  Os líderes dos partidos Republicano e Democrat...  2017-03-16    mundo
# 4  Um acordo que contou com a articulação de Rena...  2017-03-05  mercado
#
#   subcategory
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df.tail()
# Out:
#                                                    title  \
# 51497  Potencial da saúde ainda é pouco aproveitado, ...
# 51498  Vítima de racismo nega convite do Chelsea para...
# 51499  Coreia do Sul promete resgatar balsa um ano ap...
# 51500  Temer convoca PMDB para evento que debaterá te...
# 51501  Por 1 kg, Brasil perde prata no levantamento e...
#
#                                                     text        date category  \
# 51497  Start-ups da área de saúde nos EUA levantaram ...  2015-07-13  mercado
# 51498  Após ser vítima de atos racistas de torcedores...  2015-02-21  esporte
# 51499  Um ano após o naufrágio da balsa Sewol, no qua...  2015-04-16    mundo
# 51500  O vice-presidente Michel Temer (PMDB) aparece ...  2015-11-11    poder
# 51501  A paulista Bruna Piloto, 24, garantiu a oitava...  2015-07-13  esporte
#
#       subcategory
# 51497         NaN
# 51498         NaN
# 51499         NaN
# 51500         NaN
# 51501         NaN

# %%
df.shape
# Out:
# (51496, 5)

# %% [markdown]
# ### Informações Gerais

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51496 entries, 0 to 51501
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        51496 non-null  object
#  1   text         51496 non-null  object
#  2   date         51496 non-null  object
#  3   category     51496 non-null  object
#  4   subcategory  1907 non-null   object
# dtypes: object(5)
# memory usage: 2.4+ MB

# %%
df.describe()
# Out:
#                                                     title  \
# count                                               51496
# unique                                              51328
# top     Veja os lançamentos da área jurídica em destaq...
# freq                                                   37
#
#                                                      text        date  \
# count                                               51496       51496
# unique                                              51481         987
# top     O Cifras & Letras seleciona semanalmente lança...  2015-09-03
# freq                                                    3         102
#
#        category       subcategory
# count     51496              1907
# unique        9                 3
# top       poder  olimpiada-no-rio
# freq      11010              1418

# %%
df.isnull().sum()
# Out:
# title              0
# text               0
# date               0
# category           0
# subcategory    49589
# dtype: int64

# %% [markdown]
# ### Distribuição das categorias

# %%
plt.figure(figsize=(12, 5))
ax = sns.countplot(y='category', data=df)
plt.title('Distribuição das Categorias')

# Adicionar os valores no final das barras
for p in ax.patches:
    width = p.get_width()  #valor da largura da barra
    plt.text(width + 0.3,  # Posição x da anotação
             p.get_y() + p.get_height() / 2,  # Posição y da anotação
             int(width),  # Valor a ser anotado
             ha='left', va='center')  # Alinhamento da anotação

plt.show()

# %% [markdown]
# ### Distribuição das subcategorias

# %%
# Plotar a distribuição das subcategorias
plt.figure(figsize=(10, 5))
ax = sns.countplot(y='subcategory', data=df)
plt.title('Distribuição das Subcategorias')

# Adicionar os valores no final das barras
for p in ax.patches:
    width = p.get_width()  # valor da largura da barra
    plt.text(width + 0.3,  # Posição x da anotação
             p.get_y() + p.get_height() / 2,  # Posição y da anotação
             int(width),  # Valor a ser anotado
             ha='left', va='center')  # Alinhamento da anotação

plt.show()

# %% [markdown]
# ### Convertendo a coluna 'date' para datetime

# %%
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# ### Contagem de publicações por ano

# %%
publications_per_year = df['date'].dt.year.value_counts().sort_index()

# Plotando a contagem de publicações por ano
plt.figure(figsize=(10, 5))
ax = publications_per_year.plot(kind='bar')
plt.title('Número de Publicações por Ano')
plt.xlabel('Ano')
plt.ylabel('Número de Publicações')

# Ajustando os rótulos das barras para estarem horizontais
plt.xticks(rotation=0)

# Adicionando os valores em cima das barras
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                xytext=(0, 5), 
                textcoords='offset points')

plt.show()

# %% [markdown]
# ### Contagem de publicações por mês e ano

# %%
publications_per_month = df.groupby(df['date'].dt.to_period('M')).size()

# Plotando a contagem de publicações por mês e ano
plt.figure(figsize=(15, 7))
publications_per_month.plot()
plt.title('Número de Publicações por Mês e Ano')
plt.xlabel('Data')
plt.ylabel('Número de Publicações')
plt.show()

# %% [markdown]
# ### Distribuição do comprimento dos títulos

# %%
df['title_word_count'] = df['title'].apply(lambda x: len(str(x).split()))

plt.figure(figsize=(10, 5))
sns.histplot(df['title_word_count'], bins=30, kde=True)
plt.title('Distribuição do Comprimento dos Títulos por palavras')
plt.xlabel('Comprimento do Título')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ### Distribuição do comprimento dos textos por palavras

# %%
df['text_word_count'] = df['text'].apply(lambda x: len(str(x).split()))

plt.figure(figsize=(10, 5))
sns.histplot(df['text_word_count'], bins=30, kde=True)
plt.title('Distribuição do Comprimento dos Textos por palavras')
plt.xlabel('Comprimento do Texto')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ### Nuvem de palavras para os títulos

# %%
title_wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(df['title']))
plt.figure(figsize=(10, 5))
plt.imshow(title_wordcloud, interpolation='bilinear')
plt.title('Word Cloud dos Títulos')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Nuvem de palavras para os textos

# %%
text_wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(df['text']))
plt.figure(figsize=(10, 5))
plt.imshow(text_wordcloud, interpolation='bilinear')
plt.title('Word Cloud dos Textos')
plt.axis('off')
plt.show()

# %%
df
# Out:
#                                                    title  \
# 0      Haverá pressão por transparência no 'brexit', ...
# 1      Empresário confirma ter pago propina para obte...
# 2      Falta de ataques do São Paulo surpreende corin...
# 3      Líderes de comissão do Senado não veem sinais ...
# 4      Renan opera contra governo e reforma trabalhis...
# ...                                                  ...
# 51497  Potencial da saúde ainda é pouco aproveitado, ...
# 51498  Vítima de racismo nega convite do Chelsea para...
# 51499  Coreia do Sul promete resgatar balsa um ano ap...
# 51500  Temer convoca PMDB para evento que debaterá te...
# 51501  Por 1 kg, Brasil perde prata no levantamento e...
#
#                                                     text       date category  \
# 0      As negociações do "brexit" devem ocorrer a por... 2017-03-31    mundo
# 1      O empresário Augusto Ribeiro de Mendonça Neto,... 2015-03-02    poder
# 2      Cássio sorriu e pareceu sem jeito com a pergun... 2015-02-19  esporte
# 3      Os líderes dos partidos Republicano e Democrat... 2017-03-16    mundo
# 4      Um acordo que contou com a articulação de Rena... 2017-03-05  mercado
# ...                                                  ...        ...      ...
# 51497  Start-ups da área de saúde nos EUA levantaram ... 2015-07-13  mercado
# 51498  Após ser vítima de atos racistas de torcedores... 2015-02-21  esporte
# 51499  Um ano após o naufrágio da balsa Sewol, no qua... 2015-04-16    mundo
# 51500  O vice-presidente Michel Temer (PMDB) aparece ... 2015-11-11    poder
# 51501  A paulista Bruna Piloto, 24, garantiu a oitava... 2015-07-13  esporte
#
#       subcategory  title_word_count  text_word_count
# 0             NaN                10              197
# 1             NaN                10              898
# 2             NaN                10              261
# 3             NaN                12              398
# 4             NaN                11              559
# ...           ...               ...              ...
# 51497         NaN                 9              663
# 51498         NaN                11              175
# 51499         NaN                10              526
# 51500         NaN                11              280
# 51501         NaN                12              154
#
# [51496 rows x 7 columns]

# %% [markdown]
# ### Exportando o CSV com os resultados

# %%
df.to_csv('files/result.csv', index=False)
